# %%
import os
from pdfminer.high_level import extract_text
from transformers import pipeline

def read_pdf(file_path):
    text = extract_text(file_path)
    return text

def classify_problem_area(text):
    question = "What problem area does this company address?"
    areas = [
        "Vaccines or infectious diseases",
        "Gastrointestinal or metabolism",
        "Neurological disorders",
        "Cancer or tumors or oncology",
        "Dermatological conditions",
        "Organ health",
        "Mental health",
        "Other"
    ]

    nlp = pipeline("question-answering", model="mrm8488/bert-tiny-5-finetuned-squadv2")
    scores = []
    for area in areas:
        answer = nlp({"question": question, "context": text})
        scores.append(answer['score'])

    max_score_index = scores.index(max(scores))
    return areas[max_score_index]

def main():
    pdf_folder = "/Users/amin/Desktop/33/test"
    pdf_files = [f for f in os.listdir(pdf_folder) if f.endswith('.pdf')]

    for pdf_file in pdf_files:
        file_path = os.path.join(pdf_folder, pdf_file)
        text = read_pdf(file_path)
        area = classify_problem_area(text)
        print(f"{pdf_file}: {area}")

if __name__ == "__main__":
    main()
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/463 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/25.5M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/23.0 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Zehna Corporate Deck SymBiosis.pdf: Vaccines or infectious diseases
# PS_TCRR_NOTE_1.5.23.pdf: Vaccines or infectious diseases
# Grace Sciece Platform (9.2.20).pdf: Vaccines or infectious diseases
# AcuamarkDx Series A_Corp Deck.pdf: Vaccines or infectious diseases
# coding.bio_deck.pdf: Vaccines or infectious diseases
# Centurion_BioPharma-Non-Confidential_2021_2.pdf: Vaccines or infectious diseases
# JPM_SRZN_NOTE_11.28.22.pdf: Vaccines or infectious diseases
# G_ACET_IOC_4.8.21.pdf: Vaccines or infectious diseases
# C_ARQT_NOTE_11.15.22.pdf: Vaccines or infectious diseases
# B_RXRX_IOC_9.21.21.pdf: Vaccines or infectious diseases
# Dianomi Non-Confidential Slides - v3.pdf: Vaccines or infectious diseases
# KBC_MAAT.FR_IOC_12.14.21.pdf: Vaccines or infectious diseases
# Engrail Therapeutics.pdf: Vaccines or infectious diseases
# WB_VOR_IOC_1.25.22.pdf: Vaccines or infectious diseases
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-5e5b92ddad6b> in <module>
#      40
#      41 if __name__ == "__main__":
# ---> 42     main()
#
# <ipython-input-1-5e5b92ddad6b> in main()
#      36         file_path = os.path.join(pdf_folder, pdf_file)
#      37         text = read_pdf(file_path)
# ---> 38         area = classify_problem_area(text)
#      39         print(f"{pdf_file}: {area}")
#      40
#
# <ipython-input-1-5e5b92ddad6b> in classify_problem_area(text)
#      23     scores = []
#      24     for area in areas:
# ---> 25         answer = nlp({"question": question, "context": text})
#      26         scores.append(answer['score'])
#      27
#
# /opt/anaconda3/lib/python3.8/site-packages/transformers/pipelines/question_answering.py in __call__(self, *args, **kwargs)
#     390         examples = self._args_parser(*args, **kwargs)
#     391         if isinstance(examples, (list, tuple)) and len(examples) == 1:
# --> 392             return super().__call__(examples[0], **kwargs)
#     393         return super().__call__(examples, **kwargs)
#     394
#
# /opt/anaconda3/lib/python3.8/site-packages/transformers/pipelines/base.py in __call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1074             return self.iterate(inputs, preprocess_params, forward_params, postprocess_params)
#    1075         elif self.framework == "pt" and isinstance(self, ChunkPipeline):
# -> 1076             return next(
#    1077                 iter(
#    1078                     self.get_iterator(
#
# /opt/anaconda3/lib/python3.8/site-packages/transformers/pipelines/pt_utils.py in __next__(self)
#     122
#     123         # We're out of items within a batch
# --> 124         item = next(self.iterator)
#     125         processed = self.infer(item, **self.params)
#     126         # We now have a batch of "inferred things".
#
# /opt/anaconda3/lib/python3.8/site-packages/transformers/pipelines/pt_utils.py in __next__(self)
#     264
#     265         while not is_last:
# --> 266             processed = self.infer(next(self.iterator), **self.params)
#     267             if self.loader_batch_size is not None:
#     268                 if isinstance(processed, torch.Tensor):
#
# /opt/anaconda3/lib/python3.8/site-packages/transformers/pipelines/base.py in forward(self, model_inputs, **forward_params)
#     990                 with inference_context():
#     991                     model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# --> 992                     model_outputs = self._forward(model_inputs, **forward_params)
#     993                     model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#     994             else:
#
# /opt/anaconda3/lib/python3.8/site-packages/transformers/pipelines/question_answering.py in _forward(self, inputs)
#     510         example = inputs["example"]
#     511         model_inputs = {k: inputs[k] for k in self.tokenizer.model_input_names}
# --> 512         output = self.model(**model_inputs)
#     513         if isinstance(output, dict):
#     514             return {"start": output["start_logits"], "end": output["end_logits"], "example": example, **inputs}
#
# /opt/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /opt/anaconda3/lib/python3.8/site-packages/transformers/models/bert/modeling_bert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, start_positions, end_positions, output_attentions, output_hidden_states, return_dict)
#    1849         return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1850
# -> 1851         outputs = self.bert(
#    1852             input_ids,
#    1853             attention_mask=attention_mask,
#
# /opt/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /opt/anaconda3/lib/python3.8/site-packages/transformers/models/bert/modeling_bert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1017             past_key_values_length=past_key_values_length,
#    1018         )
# -> 1019         encoder_outputs = self.encoder(
#    1020             embedding_output,
#    1021             attention_mask=extended_attention_mask,
#
# /opt/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /opt/anaconda3/lib/python3.8/site-packages/transformers/models/bert/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     607                 )
#     608             else:
# --> 609                 layer_outputs = layer_module(
#     610                     hidden_states,
#     611                     attention_mask,
#
# /opt/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /opt/anaconda3/lib/python3.8/site-packages/transformers/models/bert/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     493         # decoder uni-directional self-attention cached key/values tuple is at positions 1,2
#     494         self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
# --> 495         self_attention_outputs = self.attention(
#     496             hidden_states,
#     497             attention_mask,
#
# /opt/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /opt/anaconda3/lib/python3.8/site-packages/transformers/models/bert/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     432             output_attentions,
#     433         )
# --> 434         attention_output = self.output(self_outputs[0], hidden_states)
#     435         outputs = (attention_output,) + self_outputs[1:]  # add attentions if we output them
#     436         return outputs
#
# /opt/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /opt/anaconda3/lib/python3.8/site-packages/transformers/models/bert/modeling_bert.py in forward(self, hidden_states, input_tensor)
#     382
#     383     def forward(self, hidden_states: torch.Tensor, input_tensor: torch.Tensor) -> torch.Tensor:
# --> 384         hidden_states = self.dense(hidden_states)
#     385         hidden_states = self.dropout(hidden_states)
#     386         hidden_states = self.LayerNorm(hidden_states + input_tensor)
#
# /opt/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /opt/anaconda3/lib/python3.8/site-packages/torch/nn/modules/linear.py in forward(self, input)
#     112
#     113     def forward(self, input: Tensor) -> Tensor:
# --> 114         return F.linear(input, self.weight, self.bias)
#     115
#     116     def extra_repr(self) -> str:
#
# KeyboardInterrupt:
