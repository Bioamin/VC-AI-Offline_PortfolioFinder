# %%
#Time_consuming

# %%
import os
import pdfplumber
from transformers import pipeline

# Function to extract text from a PDF file
def extract_text_from_pdf(file_path):
    with pdfplumber.open(file_path) as pdf:
        text = "\n".join([page.extract_text() for page in pdf.pages])
    return text

# Set up the question-answering pipeline
nlp = pipeline("question-answering", model="distilbert-base-uncased-distilled-squad", tokenizer="distilbert-base-uncased-distilled-squad")

folder_path = "/Users/amin/Desktop/33/test"
areas = [
    "Vaccines or infectious",
    "Gastrointestinal or metabolism",
    "Neurological",
    "Cancer or tumors or oncology",
    "Dermatological",
    "organ",
    "Mental",
    "Other"
]

for file_name in os.listdir(folder_path):
    if file_name.endswith(".pdf"):
        file_path = os.path.join(folder_path, file_name)
        text = extract_text_from_pdf(file_path)

        best_score = 0
        best_area = None

        for area in areas:
            question = f"Does the company's work focus on {area}?"
            answer = nlp({"question": question, "context": text})
            if answer["score"] > best_score:
                best_score = answer["score"]
                best_area = area

        print(f"Company: {file_name}, Related area: {best_area}")
# Out:
# Company: Zehna Corporate Deck SymBiosis.pdf, Related area: Cancer or tumors or oncology
# Company: PS_TCRR_NOTE_1.5.23.pdf, Related area: Other
# Company: Grace Sciece Platform (9.2.20).pdf, Related area: Other
# Company: AcuamarkDx Series A_Corp Deck.pdf, Related area: Other
# Company: coding.bio_deck.pdf, Related area: Other
# Company: Centurion_BioPharma-Non-Confidential_2021_2.pdf, Related area: Cancer or tumors or oncology
# Company: JPM_SRZN_NOTE_11.28.22.pdf, Related area: Other
# Company: G_ACET_IOC_4.8.21.pdf, Related area: Cancer or tumors or oncology
# Company: C_ARQT_NOTE_11.15.22.pdf, Related area: Mental
# Company: B_RXRX_IOC_9.21.21.pdf, Related area: Cancer or tumors or oncology
# Company: Dianomi Non-Confidential Slides - v3.pdf, Related area: Cancer or tumors or oncology
# Company: KBC_MAAT.FR_IOC_12.14.21.pdf, Related area: Cancer or tumors or oncology
# Company: Engrail Therapeutics.pdf, Related area: Vaccines or infectious
# ...
