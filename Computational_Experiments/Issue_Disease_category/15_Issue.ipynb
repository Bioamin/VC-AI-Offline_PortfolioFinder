# %%
#%51

# %%
import os
import pandas as pd
from transformers import pipeline
from pdfminer.high_level import extract_text

def read_pdf(file):
    text = extract_text(file)
    return text

def main_diseases(text):
    nlp = pipeline(
        "question-answering",
        model="distilbert-base-cased-distilled-squad",
        revision="626af31"
    )
    question = "What are the 3 main diseases this company solves?"
    answer = nlp(question=question, context=text)
    return answer['answer']

folder_path = '/Users/amin/Desktop/33/test'
data = []

for file in os.listdir(folder_path):
    if file.endswith('.pdf'):
        file_path = os.path.join(folder_path, file)
        text = read_pdf(file_path)
        diseases = main_diseases(text)
        keywords = diseases.split(', ')
        data.append({'File': file[:-4], 'KW': keywords})

df = pd.DataFrame(data)
df.to_csv('output.csv', index=False)
print(df)
# Out:
#                                                  File  \
# 0                      Zehna Corporate Deck SymBiosis
# 1                                 PS_TCRR_NOTE_1.5.23
# 2                      Grace Sciece Platform (9.2.20)
# 3                       AcuamarkDx Series A_Corp Deck
# 4                                     coding.bio_deck
# 5         Centurion_BioPharma-Non-Confidential_2021_2
# 6                              JPM_SRZN_NOTE_11.28.22
# 7                                   G_ACET_IOC_4.8.21
# 8                                C_ARQT_NOTE_11.15.22
# 9                                  B_RXRX_IOC_9.21.21
# 10               Dianomi Non-Confidential Slides - v3
# 11                           KBC_MAAT.FR_IOC_12.14.21
# 12                               Engrail Therapeutics
# 13                                 WB_VOR_IOC_1.25.22
# 14                                 E_FNCH_IOC_8.10.21
# 15                                CG_GRNA_IOC_12.8.22
# 16                               LT_AVXL_NOTE_6.22.21
# 17                                LT_PHGE_IOC_4.15.21
# 18          Graviton Corporate Presentation July 2022
# 19                     Bectas Tx Non-Con - Aug.1.2022
# 20                    20 080822_PRTA_Research Summary
# 21                                CT one-pager Dec 22
# 22     221003_PRE_Numab Non-Confidential Presentation
# 23        2022-3-18 Apeximmune non-confidential Baird
# 24                           Alto Overview_April 2022
# 25                        [NON-NDA] Integral Overview
# 26                               JMP_NXTC_IOC_5.26.20
# 27                   Flare Non-Con Deck November 2022
# 28  AscelpiX Corporate Presentation NON CONFIDENTI...
#
#                                                    KW
# 0                                  [stitial fibrosis]
# 1                                   [ovarian  cancer]
# 2                        [neurodegenerative diseases]
# 3   [cancers\n\nProprietary and Confidential - Not...
# 4                                         [biopharma]
# 5   [immunology, allergy, inflammation, and infect...
# 6                  [tissue damage mediated disorders]
# 7           [inflammation-induced cancer progression]
# 8                          [challenges to ARQ-151 IP]
# 9            [cancer  vaccines  and  immunotherapies]
# 10     [IL-2 MCM delivery- Graft versus host disease]
# 11  [infectious diseases or inflammatory \ndisorders]
# 12                         [anti-seizure medications]
# 13          [hematopoietic  stem  cell \ntransplants]
# 14    [UC, diarrhea, nausea and abdominal distension]
# 15                       [less \ninflammatory lipids]
# 16  [Alzheimer’s  disease  and  Parkinson’s  disease]
# 17                                            [phage]
# 18  [acute/chronic \ngraft vs. host disease and lu...
# 19  [tumor immune cell infiltration and suppress a...
# 20         [Alzheimer's and \n\nParkinson's diseases]
# 21                                           [Orphan]
# 22                 [multiple advanced \nsolid tumors]
# 23                 [psoriasis and contact dermatitis]
# 24             [anxiety, depression, and \n\nbipolar]
# 25                              [life-changing cures]
# 26                          [safety and tolerability]
# 27                           [poor PS, comorbidities]
# 28           [efficacy measured by retinal thickness]

# %%
df.to_csv('df15.csv', index=False)
df
# Out:
#                                                  File  \
# 0                      Zehna Corporate Deck SymBiosis
# 1                                 PS_TCRR_NOTE_1.5.23
# 2                      Grace Sciece Platform (9.2.20)
# 3                       AcuamarkDx Series A_Corp Deck
# 4                                     coding.bio_deck
# 5         Centurion_BioPharma-Non-Confidential_2021_2
# 6                              JPM_SRZN_NOTE_11.28.22
# 7                                   G_ACET_IOC_4.8.21
# 8                                C_ARQT_NOTE_11.15.22
# 9                                  B_RXRX_IOC_9.21.21
# 10               Dianomi Non-Confidential Slides - v3
# 11                           KBC_MAAT.FR_IOC_12.14.21
# 12                               Engrail Therapeutics
# 13                                 WB_VOR_IOC_1.25.22
# 14                                 E_FNCH_IOC_8.10.21
# 15                                CG_GRNA_IOC_12.8.22
# 16                               LT_AVXL_NOTE_6.22.21
# 17                                LT_PHGE_IOC_4.15.21
# 18          Graviton Corporate Presentation July 2022
# 19                     Bectas Tx Non-Con - Aug.1.2022
# 20                    20 080822_PRTA_Research Summary
# 21                                CT one-pager Dec 22
# 22     221003_PRE_Numab Non-Confidential Presentation
# 23        2022-3-18 Apeximmune non-confidential Baird
# 24                           Alto Overview_April 2022
# 25                        [NON-NDA] Integral Overview
# 26                               JMP_NXTC_IOC_5.26.20
# 27                   Flare Non-Con Deck November 2022
# 28  AscelpiX Corporate Presentation NON CONFIDENTI...
#
#                                                    KW
# 0                                  [stitial fibrosis]
# 1                                   [ovarian  cancer]
# 2                        [neurodegenerative diseases]
# 3   [cancers\n\nProprietary and Confidential - Not...
# 4                                         [biopharma]
# 5   [immunology, allergy, inflammation, and infect...
# 6                  [tissue damage mediated disorders]
# 7           [inflammation-induced cancer progression]
# 8                          [challenges to ARQ-151 IP]
# 9            [cancer  vaccines  and  immunotherapies]
# 10     [IL-2 MCM delivery- Graft versus host disease]
# 11  [infectious diseases or inflammatory \ndisorders]
# 12                         [anti-seizure medications]
# 13          [hematopoietic  stem  cell \ntransplants]
# 14    [UC, diarrhea, nausea and abdominal distension]
# 15                       [less \ninflammatory lipids]
# 16  [Alzheimer’s  disease  and  Parkinson’s  disease]
# 17                                            [phage]
# 18  [acute/chronic \ngraft vs. host disease and lu...
# 19  [tumor immune cell infiltration and suppress a...
# 20         [Alzheimer's and \n\nParkinson's diseases]
# 21                                           [Orphan]
# 22                 [multiple advanced \nsolid tumors]
# 23                 [psoriasis and contact dermatitis]
# 24             [anxiety, depression, and \n\nbipolar]
# 25                              [life-changing cures]
# 26                          [safety and tolerability]
# 27                           [poor PS, comorbidities]
# 28           [efficacy measured by retinal thickness]

# %%
import configparser
import pandas as pd
import openai
import re

def load_openai_api_key():
    config = configparser.ConfigParser()
    config.read("config.ini")
    return config["openai"]["api_key"]

def find_matching_area(answer):
    areas = [
        "Vaccines or infectious",
        "Gastrointestinal or metabolism",
        "Neurological",
        "Cancer or tumors or oncology",
        "Dermatological",
        "Organ health",
        "Mental",
        "Other",
    ]
    for area in areas:
        if re.search(area.lower(), answer.lower()):
            return area
    return "Other"

def get_related_area(keywords):
    openai.api_key = load_openai_api_key()
    prompt = f"Which of the following areas is more related to the keywords: {keywords}?\n\nAreas:\n" \
             "Vaccines or infectious\n" \
             "Gastrointestinal or metabolism\n" \
             "Neurological\n" \
             "Cancer or tumors or oncology\n" \
             "Dermatological\n" \
             "Organ health\n" \
             "Mental\n" \
             "Other\n\nAnswer: "

    response = openai.Completion.create(
        engine="text-davinci-002",
        prompt=prompt,
        max_tokens=10,
        n=1,
        stop=None,
        temperature=0.5,
    )

    answer = response.choices[0].text.strip()
    matching_area = find_matching_area(answer)
    return matching_area

def main():
    # Load your DataFrame
    df = pd.read_csv("df15.csv")

    # Add a new column 'Issue'
    df["Issue"] = df["KW"].apply(get_related_area)

    # Drop the 'KW' column
    df = df.drop(columns=["KW"])
    print(df)

    # Save the DataFrame to a new CSV file
    df.to_csv("issue15.csv", index=False)

if __name__ == "__main__":
    main()
# Out:
#                                                  File  \
# 0                      Zehna Corporate Deck SymBiosis
# 1                                 PS_TCRR_NOTE_1.5.23
# 2                      Grace Sciece Platform (9.2.20)
# 3                       AcuamarkDx Series A_Corp Deck
# 4                                     coding.bio_deck
# 5         Centurion_BioPharma-Non-Confidential_2021_2
# 6                              JPM_SRZN_NOTE_11.28.22
# 7                                   G_ACET_IOC_4.8.21
# 8                                C_ARQT_NOTE_11.15.22
# 9                                  B_RXRX_IOC_9.21.21
# 10               Dianomi Non-Confidential Slides - v3
# 11                           KBC_MAAT.FR_IOC_12.14.21
# 12                               Engrail Therapeutics
# 13                                 WB_VOR_IOC_1.25.22
# 14                                 E_FNCH_IOC_8.10.21
# 15                                CG_GRNA_IOC_12.8.22
# 16                               LT_AVXL_NOTE_6.22.21
# 17                                LT_PHGE_IOC_4.15.21
# 18          Graviton Corporate Presentation July 2022
# 19                     Bectas Tx Non-Con - Aug.1.2022
# 20                    20 080822_PRTA_Research Summary
# 21                                CT one-pager Dec 22
# 22     221003_PRE_Numab Non-Confidential Presentation
# 23        2022-3-18 Apeximmune non-confidential Baird
# 24                           Alto Overview_April 2022
# 25                        [NON-NDA] Integral Overview
# 26                               JMP_NXTC_IOC_5.26.20
# 27                   Flare Non-Con Deck November 2022
# 28  AscelpiX Corporate Presentation NON CONFIDENTI...
#
#                              Issue
# 0     Cancer or tumors or oncology
# 1     Cancer or tumors or oncology
# 2                     Neurological
# 3     Cancer or tumors or oncology
# 4     Cancer or tumors or oncology
# 5           Vaccines or infectious
# 6                            Other
# 7     Cancer or tumors or oncology
# 8                            Other
# 9     Cancer or tumors or oncology
# 10    Cancer or tumors or oncology
# 11          Vaccines or infectious
# 12                    Neurological
# 13    Cancer or tumors or oncology
# 14  Gastrointestinal or metabolism
# 15  Gastrointestinal or metabolism
# 16                    Neurological
# 17          Vaccines or infectious
# 18    Cancer or tumors or oncology
# 19    Cancer or tumors or oncology
# 20                    Neurological
# 21                           Other
# 22    Cancer or tumors or oncology
# 23                  Dermatological
# 24                          Mental
# 25    Cancer or tumors or oncology
# 26          Vaccines or infectious
# 27                          Mental
# 28                    Neurological
