# %%
###############################################################################
# Author: Amin Boroomand, March 2023
#Owner: Symbiosis.vc
# This code aims to find investment names using different 
# PdF readers and different NLP packages to find which is
# accurate in finding investment name. In this code we cropped PDF margines
################################################################################

# %%
#imports
import os
import subprocess
import PyPDF2
import pdfminer
import pdfrw
import spacy
import pandas as pd
from stanfordnlp.server import CoreNLPClient
import os
from pdfCropMargins import crop
import re
from pdfminer.high_level import extract_text
import subprocess

# %%
#setting CORENLP_HOME environment variable
corenlp_home_path = '/Users/amin/Desktop/33/code_test/stanford-corenlp-4.5.3'
os.environ['CORENLP_HOME'] = corenlp_home_path

# %%
#reading files with different PDF reader packages
def read_pdf_file(pdf_reader, file_path):
    if pdf_reader == 'PyPDF2':
        return read_pdf_PyPDF2(file_path)
    elif pdf_reader == 'pdfminer':
        return read_pdf_pdfminer(file_path)
    elif pdf_reader == 'pdfrw':
        return read_pdf_pdfrw(file_path)
    
def read_pdf_PyPDF2(file_path):
    pdf_file = open(file_path, 'rb')
    pdf_reader = PyPDF2.PdfFileReader(pdf_file)
    text = ''
    for page_num in range(pdf_reader.numPages):
        text += pdf_reader.getPage(page_num).extractText()
    pdf_file.close()
    return text

def read_pdf_pdfminer(file_path):
    text = extract_text(file_path)
    return text


def read_pdf_pdfrw(file_path):
    pdf = pdfrw.PdfReader(file_path)
    text = ''
    for page in pdf.pages:
        try:
            text += page.Contents.stream.decode()
        except (AttributeError, TypeError, pdfrw.errors.PdfParseError):
            pass
    return text

# %%
#cleaning

def clean_text(text):
    # Remove header/footer
    text = re.sub(r"Header:\s.*", "", text, flags=re.MULTILINE)
    text = re.sub(r"Footer:\s.*", "", text, flags=re.MULTILINE)

    # Remove page numbers and unnecessary information
    text = re.sub(r"Page\s\d+", "", text)
    text = re.sub(r"\n\d+\n", "", text)

    return text

#corp margine
def crop_pdf_margins(file_path, pdf_folder):
    cropped_folder = os.path.join(pdf_folder, "cropped")
    os.makedirs(cropped_folder, exist_ok=True)
    file_name = os.path.basename(file_path)
    cropped_file_name = file_name[:-4] + "_cropped.pdf"
    cropped_file_path = os.path.join(cropped_folder, cropped_file_name)

    cmd = f'pdf-crop-margins -o "{cropped_file_path}" -all -p 1 -a4 -40 -40 -120 -40 "{file_path}"'
    
    try:
        result = subprocess.run(cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE, shell=True, text=True)
        output = result.stdout
        error = result.stderr
        print("Output:", output)
        print("Error:", error)
        
        print(f"Cropping: {file_path}")
        print(f"Saving cropped file to: {cropped_file_path}")
        
        if not os.path.exists(cropped_file_path):
            print("Cropped file not found. Please check the cropping process.")
            return file_path

    except Exception as e:
        print(f"Error cropping {file_path}: {str(e)}")
        return file_path

    return cropped_file_path

# %%
#find company name using different NLP tools
def extract_company_name(nlp_package, text):
    if nlp_package == 'SpaCy':
        return extract_company_name_spacy(text)
    elif nlp_package == 'Stanford NLP':
        return extract_company_name_stanford(text)


def extract_company_name_spacy(text):
    nlp = spacy.load("en_core_web_sm")
    doc = nlp(text)
    for ent in doc.ents:
        if ent.label_ == "ORG":
            return ent.text
    return None

def extract_company_name_stanford(text):
    with CoreNLPClient(annotators=['ner'], timeout=600000,
                       memory='4G', stdout='corenlp_stdout.log',
                       stderr='corenlp_stderr.log') as client:
        annotated = client.annotate(text)
        for sentence in annotated.sentence:
            for token in sentence.token:
                if token.ner == 'ORGANIZATION':
                    return token.word
    return None

# %%
def main():
    pdf_readers = ['PyPDF2', 'pdfminer', 'pdfrw']
    nlp_packages = ['SpaCy']
    pdf_folder = '/Users/amin/Desktop/33/test'

    data = {'File_name': [], 'PyPDF2_SpaCy': [], 'pdfminer_SpaCy': [], 'pdfrw_SpaCy': []}
    df = pd.DataFrame(data)

    for file in os.listdir(pdf_folder):
        if file.endswith(".pdf"):
            file_path = os.path.join(pdf_folder, file)
            cropped_file_path = crop_pdf_margins(file_path, pdf_folder)
            file_name = file[:-4]
            df = df.append({'File_name': file_name}, ignore_index=True)

            for pdf_reader in pdf_readers:
                text = read_pdf_file(pdf_reader, cropped_file_path)
                text = clean_text(text)
                for nlp_package in nlp_packages:
                    company_name = extract_company_name(nlp_package, text)
                    column_name = f"{pdf_reader}_{nlp_package}"
                    df.loc[df['File_name'] == file_name, column_name] = company_name

    print(df)
    df.to_csv('names_test_NLP_cropp.csv', index=False)

if __name__ == "__main__":
    main()
# Out:
# Output:
# Error:
# Usage: pdf-crop-margins [-h] [-o OUTFILE_PATH_OR_DIR] [-v] [-gui] [-p PCT] [-p4 PCT PCT PCT PCT] [-pt] [-a BP] [-a4 BP BP BP BP] [-cs] [-csm4 BP BP BP BP] [-ap BP] [-ap4 BP BP BP BP] [-u] [-m INT]
#                         [-m4 INT INT INT INT] [-mp INT] [-s] [-ms INT] [-e] [-g PAGESTR] [-c [d|m|p|gr|gb|o]] [-gs] [-gsr] [-t BYTEVAL] [-nb INT] [-ns INT] [-x DPI] [-y DPI] [-sr STR] [-gf INT]
#                         [-b [m|c|t|a|b]] [-f [m|c|t|a|b]] [-r] [-A] [-gsf] [-nc] [-pv PROG] [-mo] [-q] [-nco] [-pf] [-sc STR] [-su STR] [-ss STR] [-pw PASSWD] [-pc] [-khc] [-kvc] [-spr FLOAT:FLOAT]
#                         [-prw FLOAT FLOAT FLOAT FLOAT] [-dcb STR] [-dcw STR] [-i] [-pdl] [-gsp PATH] [-ppp PATH] [--version] [-wcdf FILEPATH]
#                         PDF_FILE [PDF_FILE ...]
# Error in pdf-crop-margins (pdfCropMargins): argument -a/--absoluteOffset: invalid float value: 'll'
#
# Cropping: /Users/amin/Desktop/33/test/Zehna Corporate Deck SymBiosis.pdf
# Saving cropped file to: /Users/amin/Desktop/33/test/cropped/Zehna Corporate Deck SymBiosis_cropped.pdf
# Output:
# Error:
# Usage: pdf-crop-margins [-h] [-o OUTFILE_PATH_OR_DIR] [-v] [-gui] [-p PCT] [-p4 PCT PCT PCT PCT] [-pt] [-a BP] [-a4 BP BP BP BP] [-cs] [-csm4 BP BP BP BP] [-ap BP] [-ap4 BP BP BP BP] [-u] [-m INT]
#                         [-m4 INT INT INT INT] [-mp INT] [-s] [-ms INT] [-e] [-g PAGESTR] [-c [d|m|p|gr|gb|o]] [-gs] [-gsr] [-t BYTEVAL] [-nb INT] [-ns INT] [-x DPI] [-y DPI] [-sr STR] [-gf INT]
#                         [-b [m|c|t|a|b]] [-f [m|c|t|a|b]] [-r] [-A] [-gsf] [-nc] [-pv PROG] [-mo] [-q] [-nco] [-pf] [-sc STR] [-su STR] [-ss STR] [-pw PASSWD] [-pc] [-khc] [-kvc] [-spr FLOAT:FLOAT]
#                         [-prw FLOAT FLOAT FLOAT FLOAT] [-dcb STR] [-dcw STR] [-i] [-pdl] [-gsp PATH] [-ppp PATH] [--version] [-wcdf FILEPATH]
#                         PDF_FILE [PDF_FILE ...]
# Error in pdf-crop-margins (pdfCropMargins): argument -a/--absoluteOffset: invalid float value: 'll'
#
# Cropping: /Users/amin/Desktop/33/test/PS_TCRR_NOTE_1.5.23.pdf
# Saving cropped file to: /Users/amin/Desktop/33/test/cropped/PS_TCRR_NOTE_1.5.23_cropped.pdf
# Output:
# Error:
# Usage: pdf-crop-margins [-h] [-o OUTFILE_PATH_OR_DIR] [-v] [-gui] [-p PCT] [-p4 PCT PCT PCT PCT] [-pt] [-a BP] [-a4 BP BP BP BP] [-cs] [-csm4 BP BP BP BP] [-ap BP] [-ap4 BP BP BP BP] [-u] [-m INT]
#                         [-m4 INT INT INT INT] [-mp INT] [-s] [-ms INT] [-e] [-g PAGESTR] [-c [d|m|p|gr|gb|o]] [-gs] [-gsr] [-t BYTEVAL] [-nb INT] [-ns INT] [-x DPI] [-y DPI] [-sr STR] [-gf INT]
#                         [-b [m|c|t|a|b]] [-f [m|c|t|a|b]] [-r] [-A] [-gsf] [-nc] [-pv PROG] [-mo] [-q] [-nco] [-pf] [-sc STR] [-su STR] [-ss STR] [-pw PASSWD] [-pc] [-khc] [-kvc] [-spr FLOAT:FLOAT]
#                         [-prw FLOAT FLOAT FLOAT FLOAT] [-dcb STR] [-dcw STR] [-i] [-pdl] [-gsp PATH] [-ppp PATH] [--version] [-wcdf FILEPATH]
#                         PDF_FILE [PDF_FILE ...]
# Error in pdf-crop-margins (pdfCropMargins): argument -a/--absoluteOffset: invalid float value: 'll'
#
# Cropping: /Users/amin/Desktop/33/test/Grace Sciece Platform (9.2.20).pdf
# Saving cropped file to: /Users/amin/Desktop/33/test/cropped/Grace Sciece Platform (9.2.20)_cropped.pdf
# Output:
# Error:
# Usage: pdf-crop-margins [-h] [-o OUTFILE_PATH_OR_DIR] [-v] [-gui] [-p PCT] [-p4 PCT PCT PCT PCT] [-pt] [-a BP] [-a4 BP BP BP BP] [-cs] [-csm4 BP BP BP BP] [-ap BP] [-ap4 BP BP BP BP] [-u] [-m INT]
#                         [-m4 INT INT INT INT] [-mp INT] [-s] [-ms INT] [-e] [-g PAGESTR] [-c [d|m|p|gr|gb|o]] [-gs] [-gsr] [-t BYTEVAL] [-nb INT] [-ns INT] [-x DPI] [-y DPI] [-sr STR] [-gf INT]
#                         [-b [m|c|t|a|b]] [-f [m|c|t|a|b]] [-r] [-A] [-gsf] [-nc] [-pv PROG] [-mo] [-q] [-nco] [-pf] [-sc STR] [-su STR] [-ss STR] [-pw PASSWD] [-pc] [-khc] [-kvc] [-spr FLOAT:FLOAT]
#                         [-prw FLOAT FLOAT FLOAT FLOAT] [-dcb STR] [-dcw STR] [-i] [-pdl] [-gsp PATH] [-ppp PATH] [--version] [-wcdf FILEPATH]
#                         PDF_FILE [PDF_FILE ...]
# Error in pdf-crop-margins (pdfCropMargins): argument -a/--absoluteOffset: invalid float value: 'll'
#
# Cropping: /Users/amin/Desktop/33/test/AcuamarkDx Series A_Corp Deck.pdf
# Saving cropped file to: /Users/amin/Desktop/33/test/cropped/AcuamarkDx Series A_Corp Deck_cropped.pdf
# Output:
# Error:
# Usage: pdf-crop-margins [-h] [-o OUTFILE_PATH_OR_DIR] [-v] [-gui] [-p PCT] [-p4 PCT PCT PCT PCT] [-pt] [-a BP] [-a4 BP BP BP BP] [-cs] [-csm4 BP BP BP BP] [-ap BP] [-ap4 BP BP BP BP] [-u] [-m INT]
#                         [-m4 INT INT INT INT] [-mp INT] [-s] [-ms INT] [-e] [-g PAGESTR] [-c [d|m|p|gr|gb|o]] [-gs] [-gsr] [-t BYTEVAL] [-nb INT] [-ns INT] [-x DPI] [-y DPI] [-sr STR] [-gf INT]
#                         [-b [m|c|t|a|b]] [-f [m|c|t|a|b]] [-r] [-A] [-gsf] [-nc] [-pv PROG] [-mo] [-q] [-nco] [-pf] [-sc STR] [-su STR] [-ss STR] [-pw PASSWD] [-pc] [-khc] [-kvc] [-spr FLOAT:FLOAT]
#                         [-prw FLOAT FLOAT FLOAT FLOAT] [-dcb STR] [-dcw STR] [-i] [-pdl] [-gsp PATH] [-ppp PATH] [--version] [-wcdf FILEPATH]
#                         PDF_FILE [PDF_FILE ...]
# Error in pdf-crop-margins (pdfCropMargins): argument -a/--absoluteOffset: invalid float value: 'll'
#
# Cropping: /Users/amin/Desktop/33/test/coding.bio_deck.pdf
# Saving cropped file to: /Users/amin/Desktop/33/test/cropped/coding.bio_deck_cropped.pdf
# Output:
# Error:
# Usage: pdf-crop-margins [-h] [-o OUTFILE_PATH_OR_DIR] [-v] [-gui] [-p PCT] [-p4 PCT PCT PCT PCT] [-pt] [-a BP] [-a4 BP BP BP BP] [-cs] [-csm4 BP BP BP BP] [-ap BP] [-ap4 BP BP BP BP] [-u] [-m INT]
#                         [-m4 INT INT INT INT] [-mp INT] [-s] [-ms INT] [-e] [-g PAGESTR] [-c [d|m|p|gr|gb|o]] [-gs] [-gsr] [-t BYTEVAL] [-nb INT] [-ns INT] [-x DPI] [-y DPI] [-sr STR] [-gf INT]
#                         [-b [m|c|t|a|b]] [-f [m|c|t|a|b]] [-r] [-A] [-gsf] [-nc] [-pv PROG] [-mo] [-q] [-nco] [-pf] [-sc STR] [-su STR] [-ss STR] [-pw PASSWD] [-pc] [-khc] [-kvc] [-spr FLOAT:FLOAT]
#                         [-prw FLOAT FLOAT FLOAT FLOAT] [-dcb STR] [-dcw STR] [-i] [-pdl] [-gsp PATH] [-ppp PATH] [--version] [-wcdf FILEPATH]
#                         PDF_FILE [PDF_FILE ...]
# Error in pdf-crop-margins (pdfCropMargins): argument -a/--absoluteOffset: invalid float value: 'll'
#
# Cropping: /Users/amin/Desktop/33/test/Centurion_BioPharma-Non-Confidential_2021_2.pdf
# Saving cropped file to: /Users/amin/Desktop/33/test/cropped/Centurion_BioPharma-Non-Confidential_2021_2_cropped.pdf
# Output:
# Error:
# Usage: pdf-crop-margins [-h] [-o OUTFILE_PATH_OR_DIR] [-v] [-gui] [-p PCT] [-p4 PCT PCT PCT PCT] [-pt] [-a BP] [-a4 BP BP BP BP] [-cs] [-csm4 BP BP BP BP] [-ap BP] [-ap4 BP BP BP BP] [-u] [-m INT]
#                         [-m4 INT INT INT INT] [-mp INT] [-s] [-ms INT] [-e] [-g PAGESTR] [-c [d|m|p|gr|gb|o]] [-gs] [-gsr] [-t BYTEVAL] [-nb INT] [-ns INT] [-x DPI] [-y DPI] [-sr STR] [-gf INT]
#                         [-b [m|c|t|a|b]] [-f [m|c|t|a|b]] [-r] [-A] [-gsf] [-nc] [-pv PROG] [-mo] [-q] [-nco] [-pf] [-sc STR] [-su STR] [-ss STR] [-pw PASSWD] [-pc] [-khc] [-kvc] [-spr FLOAT:FLOAT]
#                         [-prw FLOAT FLOAT FLOAT FLOAT] [-dcb STR] [-dcw STR] [-i] [-pdl] [-gsp PATH] [-ppp PATH] [--version] [-wcdf FILEPATH]
#                         PDF_FILE [PDF_FILE ...]
# Error in pdf-crop-margins (pdfCropMargins): argument -a/--absoluteOffset: invalid float value: 'll'
#
# Cropping: /Users/amin/Desktop/33/test/JPM_SRZN_NOTE_11.28.22.pdf
# Saving cropped file to: /Users/amin/Desktop/33/test/cropped/JPM_SRZN_NOTE_11.28.22_cropped.pdf
# Output:
# Error:
# Usage: pdf-crop-margins [-h] [-o OUTFILE_PATH_OR_DIR] [-v] [-gui] [-p PCT] [-p4 PCT PCT PCT PCT] [-pt] [-a BP] [-a4 BP BP BP BP] [-cs] [-csm4 BP BP BP BP] [-ap BP] [-ap4 BP BP BP BP] [-u] [-m INT]
#                         [-m4 INT INT INT INT] [-mp INT] [-s] [-ms INT] [-e] [-g PAGESTR] [-c [d|m|p|gr|gb|o]] [-gs] [-gsr] [-t BYTEVAL] [-nb INT] [-ns INT] [-x DPI] [-y DPI] [-sr STR] [-gf INT]
#                         [-b [m|c|t|a|b]] [-f [m|c|t|a|b]] [-r] [-A] [-gsf] [-nc] [-pv PROG] [-mo] [-q] [-nco] [-pf] [-sc STR] [-su STR] [-ss STR] [-pw PASSWD] [-pc] [-khc] [-kvc] [-spr FLOAT:FLOAT]
#                         [-prw FLOAT FLOAT FLOAT FLOAT] [-dcb STR] [-dcw STR] [-i] [-pdl] [-gsp PATH] [-ppp PATH] [--version] [-wcdf FILEPATH]
#                         PDF_FILE [PDF_FILE ...]
# Error in pdf-crop-margins (pdfCropMargins): argument -a/--absoluteOffset: invalid float value: 'll'
# Cropping: /Users/amin/Desktop/33/test/G_ACET_IOC_4.8.21.pdf
# Saving cropped file to: /Users/amin/Desktop/33/test/cropped/G_ACET_IOC_4.8.21_cropped.pdf
# Output:
# Error:
# Usage: pdf-crop-margins [-h] [-o OUTFILE_PATH_OR_DIR] [-v] [-gui] [-p PCT] [-p4 PCT PCT PCT PCT] [-pt] [-a BP] [-a4 BP BP BP BP] [-cs] [-csm4 BP BP BP BP] [-ap BP] [-ap4 BP BP BP BP] [-u] [-m INT]
#                         [-m4 INT INT INT INT] [-mp INT] [-s] [-ms INT] [-e] [-g PAGESTR] [-c [d|m|p|gr|gb|o]] [-gs] [-gsr] [-t BYTEVAL] [-nb INT] [-ns INT] [-x DPI] [-y DPI] [-sr STR] [-gf INT]
#                         [-b [m|c|t|a|b]] [-f [m|c|t|a|b]] [-r] [-A] [-gsf] [-nc] [-pv PROG] [-mo] [-q] [-nco] [-pf] [-sc STR] [-su STR] [-ss STR] [-pw PASSWD] [-pc] [-khc] [-kvc] [-spr FLOAT:FLOAT]
#                         [-prw FLOAT FLOAT FLOAT FLOAT] [-dcb STR] [-dcw STR] [-i] [-pdl] [-gsp PATH] [-ppp PATH] [--version] [-wcdf FILEPATH]
#                         PDF_FILE [PDF_FILE ...]
# Error in pdf-crop-margins (pdfCropMargins): argument -a/--absoluteOffset: invalid float value: 'll'
#
# Cropping: /Users/amin/Desktop/33/test/C_ARQT_NOTE_11.15.22.pdf
# Saving cropped file to: /Users/amin/Desktop/33/test/cropped/C_ARQT_NOTE_11.15.22_cropped.pdf
# Output:
# Error:
# Usage: pdf-crop-margins [-h] [-o OUTFILE_PATH_OR_DIR] [-v] [-gui] [-p PCT] [-p4 PCT PCT PCT PCT] [-pt] [-a BP] [-a4 BP BP BP BP] [-cs] [-csm4 BP BP BP BP] [-ap BP] [-ap4 BP BP BP BP] [-u] [-m INT]
#                         [-m4 INT INT INT INT] [-mp INT] [-s] [-ms INT] [-e] [-g PAGESTR] [-c [d|m|p|gr|gb|o]] [-gs] [-gsr] [-t BYTEVAL] [-nb INT] [-ns INT] [-x DPI] [-y DPI] [-sr STR] [-gf INT]
#                         [-b [m|c|t|a|b]] [-f [m|c|t|a|b]] [-r] [-A] [-gsf] [-nc] [-pv PROG] [-mo] [-q] [-nco] [-pf] [-sc STR] [-su STR] [-ss STR] [-pw PASSWD] [-pc] [-khc] [-kvc] [-spr FLOAT:FLOAT]
#                         [-prw FLOAT FLOAT FLOAT FLOAT] [-dcb STR] [-dcw STR] [-i] [-pdl] [-gsp PATH] [-ppp PATH] [--version] [-wcdf FILEPATH]
#                         PDF_FILE [PDF_FILE ...]
# Error in pdf-crop-margins (pdfCropMargins): argument -a/--absoluteOffset: invalid float value: 'll'
#
# Cropping: /Users/amin/Desktop/33/test/B_RXRX_IOC_9.21.21.pdf
# Saving cropped file to: /Users/amin/Desktop/33/test/cropped/B_RXRX_IOC_9.21.21_cropped.pdf
# Output:
# Error:
# Usage: pdf-crop-margins [-h] [-o OUTFILE_PATH_OR_DIR] [-v] [-gui] [-p PCT] [-p4 PCT PCT PCT PCT] [-pt] [-a BP] [-a4 BP BP BP BP] [-cs] [-csm4 BP BP BP BP] [-ap BP] [-ap4 BP BP BP BP] [-u] [-m INT]
#                         [-m4 INT INT INT INT] [-mp INT] [-s] [-ms INT] [-e] [-g PAGESTR] [-c [d|m|p|gr|gb|o]] [-gs] [-gsr] [-t BYTEVAL] [-nb INT] [-ns INT] [-x DPI] [-y DPI] [-sr STR] [-gf INT]
#                         [-b [m|c|t|a|b]] [-f [m|c|t|a|b]] [-r] [-A] [-gsf] [-nc] [-pv PROG] [-mo] [-q] [-nco] [-pf] [-sc STR] [-su STR] [-ss STR] [-pw PASSWD] [-pc] [-khc] [-kvc] [-spr FLOAT:FLOAT]
#                         [-prw FLOAT FLOAT FLOAT FLOAT] [-dcb STR] [-dcw STR] [-i] [-pdl] [-gsp PATH] [-ppp PATH] [--version] [-wcdf FILEPATH]
#                         PDF_FILE [PDF_FILE ...]
# Error in pdf-crop-margins (pdfCropMargins): argument -a/--absoluteOffset: invalid float value: 'll'
#
# Cropping: /Users/amin/Desktop/33/test/Dianomi Non-Confidential Slides - v3.pdf
# Saving cropped file to: /Users/amin/Desktop/33/test/cropped/Dianomi Non-Confidential Slides - v3_cropped.pdf
# Output:
# Error:
# Usage: pdf-crop-margins [-h] [-o OUTFILE_PATH_OR_DIR] [-v] [-gui] [-p PCT] [-p4 PCT PCT PCT PCT] [-pt] [-a BP] [-a4 BP BP BP BP] [-cs] [-csm4 BP BP BP BP] [-ap BP] [-ap4 BP BP BP BP] [-u] [-m INT]
#                         [-m4 INT INT INT INT] [-mp INT] [-s] [-ms INT] [-e] [-g PAGESTR] [-c [d|m|p|gr|gb|o]] [-gs] [-gsr] [-t BYTEVAL] [-nb INT] [-ns INT] [-x DPI] [-y DPI] [-sr STR] [-gf INT]
#                         [-b [m|c|t|a|b]] [-f [m|c|t|a|b]] [-r] [-A] [-gsf] [-nc] [-pv PROG] [-mo] [-q] [-nco] [-pf] [-sc STR] [-su STR] [-ss STR] [-pw PASSWD] [-pc] [-khc] [-kvc] [-spr FLOAT:FLOAT]
#                         [-prw FLOAT FLOAT FLOAT FLOAT] [-dcb STR] [-dcw STR] [-i] [-pdl] [-gsp PATH] [-ppp PATH] [--version] [-wcdf FILEPATH]
#                         PDF_FILE [PDF_FILE ...]
# Error in pdf-crop-margins (pdfCropMargins): argument -a/--absoluteOffset: invalid float value: 'll'
#
# Cropping: /Users/amin/Desktop/33/test/KBC_MAAT.FR_IOC_12.14.21.pdf
# Saving cropped file to: /Users/amin/Desktop/33/test/cropped/KBC_MAAT.FR_IOC_12.14.21_cropped.pdf
# Output:
# Error:
# Usage: pdf-crop-margins [-h] [-o OUTFILE_PATH_OR_DIR] [-v] [-gui] [-p PCT] [-p4 PCT PCT PCT PCT] [-pt] [-a BP] [-a4 BP BP BP BP] [-cs] [-csm4 BP BP BP BP] [-ap BP] [-ap4 BP BP BP BP] [-u] [-m INT]
#                         [-m4 INT INT INT INT] [-mp INT] [-s] [-ms INT] [-e] [-g PAGESTR] [-c [d|m|p|gr|gb|o]] [-gs] [-gsr] [-t BYTEVAL] [-nb INT] [-ns INT] [-x DPI] [-y DPI] [-sr STR] [-gf INT]
#                         [-b [m|c|t|a|b]] [-f [m|c|t|a|b]] [-r] [-A] [-gsf] [-nc] [-pv PROG] [-mo] [-q] [-nco] [-pf] [-sc STR] [-su STR] [-ss STR] [-pw PASSWD] [-pc] [-khc] [-kvc] [-spr FLOAT:FLOAT]
#                         [-prw FLOAT FLOAT FLOAT FLOAT] [-dcb STR] [-dcw STR] [-i] [-pdl] [-gsp PATH] [-ppp PATH] [--version] [-wcdf FILEPATH]
#                         PDF_FILE [PDF_FILE ...]
# Error in pdf-crop-margins (pdfCropMargins): argument -a/--absoluteOffset: invalid float value: 'll'
#
# Cropping: /Users/amin/Desktop/33/test/Engrail Therapeutics.pdf
# Saving cropped file to: /Users/amin/Desktop/33/test/cropped/Engrail Therapeutics_cropped.pdf
# Output:
# Error:
# Usage: pdf-crop-margins [-h] [-o OUTFILE_PATH_OR_DIR] [-v] [-gui] [-p PCT] [-p4 PCT PCT PCT PCT] [-pt] [-a BP] [-a4 BP BP BP BP] [-cs] [-csm4 BP BP BP BP] [-ap BP] [-ap4 BP BP BP BP] [-u] [-m INT]
#                         [-m4 INT INT INT INT] [-mp INT] [-s] [-ms INT] [-e] [-g PAGESTR] [-c [d|m|p|gr|gb|o]] [-gs] [-gsr] [-t BYTEVAL] [-nb INT] [-ns INT] [-x DPI] [-y DPI] [-sr STR] [-gf INT]
#                         [-b [m|c|t|a|b]] [-f [m|c|t|a|b]] [-r] [-A] [-gsf] [-nc] [-pv PROG] [-mo] [-q] [-nco] [-pf] [-sc STR] [-su STR] [-ss STR] [-pw PASSWD] [-pc] [-khc] [-kvc] [-spr FLOAT:FLOAT]
#                         [-prw FLOAT FLOAT FLOAT FLOAT] [-dcb STR] [-dcw STR] [-i] [-pdl] [-gsp PATH] [-ppp PATH] [--version] [-wcdf FILEPATH]
#                         PDF_FILE [PDF_FILE ...]
# Error in pdf-crop-margins (pdfCropMargins): argument -a/--absoluteOffset: invalid float value: 'll'
#
# Cropping: /Users/amin/Desktop/33/test/WB_VOR_IOC_1.25.22.pdf
# Saving cropped file to: /Users/amin/Desktop/33/test/cropped/WB_VOR_IOC_1.25.22_cropped.pdf
# Output:
# Error:
# Usage: pdf-crop-margins [-h] [-o OUTFILE_PATH_OR_DIR] [-v] [-gui] [-p PCT] [-p4 PCT PCT PCT PCT] [-pt] [-a BP] [-a4 BP BP BP BP] [-cs] [-csm4 BP BP BP BP] [-ap BP] [-ap4 BP BP BP BP] [-u] [-m INT]
#                         [-m4 INT INT INT INT] [-mp INT] [-s] [-ms INT] [-e] [-g PAGESTR] [-c [d|m|p|gr|gb|o]] [-gs] [-gsr] [-t BYTEVAL] [-nb INT] [-ns INT] [-x DPI] [-y DPI] [-sr STR] [-gf INT]
#                         [-b [m|c|t|a|b]] [-f [m|c|t|a|b]] [-r] [-A] [-gsf] [-nc] [-pv PROG] [-mo] [-q] [-nco] [-pf] [-sc STR] [-su STR] [-ss STR] [-pw PASSWD] [-pc] [-khc] [-kvc] [-spr FLOAT:FLOAT]
#                         [-prw FLOAT FLOAT FLOAT FLOAT] [-dcb STR] [-dcw STR] [-i] [-pdl] [-gsp PATH] [-ppp PATH] [--version] [-wcdf FILEPATH]
#                         PDF_FILE [PDF_FILE ...]
# Error in pdf-crop-margins (pdfCropMargins): argument -a/--absoluteOffset: invalid float value: 'll'
#
# Cropping: /Users/amin/Desktop/33/test/E_FNCH_IOC_8.10.21.pdf
# Saving cropped file to: /Users/amin/Desktop/33/test/cropped/E_FNCH_IOC_8.10.21_cropped.pdf
# Output:
# Error:
# Usage: pdf-crop-margins [-h] [-o OUTFILE_PATH_OR_DIR] [-v] [-gui] [-p PCT] [-p4 PCT PCT PCT PCT] [-pt] [-a BP] [-a4 BP BP BP BP] [-cs] [-csm4 BP BP BP BP] [-ap BP] [-ap4 BP BP BP BP] [-u] [-m INT]
#                         [-m4 INT INT INT INT] [-mp INT] [-s] [-ms INT] [-e] [-g PAGESTR] [-c [d|m|p|gr|gb|o]] [-gs] [-gsr] [-t BYTEVAL] [-nb INT] [-ns INT] [-x DPI] [-y DPI] [-sr STR] [-gf INT]
#                         [-b [m|c|t|a|b]] [-f [m|c|t|a|b]] [-r] [-A] [-gsf] [-nc] [-pv PROG] [-mo] [-q] [-nco] [-pf] [-sc STR] [-su STR] [-ss STR] [-pw PASSWD] [-pc] [-khc] [-kvc] [-spr FLOAT:FLOAT]
#                         [-prw FLOAT FLOAT FLOAT FLOAT] [-dcb STR] [-dcw STR] [-i] [-pdl] [-gsp PATH] [-ppp PATH] [--version] [-wcdf FILEPATH]
#                         PDF_FILE [PDF_FILE ...]
# Error in pdf-crop-margins (pdfCropMargins): argument -a/--absoluteOffset: invalid float value: 'll'
# Cropping: /Users/amin/Desktop/33/test/CG_GRNA_IOC_12.8.22.pdf
# Saving cropped file to: /Users/amin/Desktop/33/test/cropped/CG_GRNA_IOC_12.8.22_cropped.pdf
# Output:
# Error:
# Usage: pdf-crop-margins [-h] [-o OUTFILE_PATH_OR_DIR] [-v] [-gui] [-p PCT] [-p4 PCT PCT PCT PCT] [-pt] [-a BP] [-a4 BP BP BP BP] [-cs] [-csm4 BP BP BP BP] [-ap BP] [-ap4 BP BP BP BP] [-u] [-m INT]
#                         [-m4 INT INT INT INT] [-mp INT] [-s] [-ms INT] [-e] [-g PAGESTR] [-c [d|m|p|gr|gb|o]] [-gs] [-gsr] [-t BYTEVAL] [-nb INT] [-ns INT] [-x DPI] [-y DPI] [-sr STR] [-gf INT]
#                         [-b [m|c|t|a|b]] [-f [m|c|t|a|b]] [-r] [-A] [-gsf] [-nc] [-pv PROG] [-mo] [-q] [-nco] [-pf] [-sc STR] [-su STR] [-ss STR] [-pw PASSWD] [-pc] [-khc] [-kvc] [-spr FLOAT:FLOAT]
#                         [-prw FLOAT FLOAT FLOAT FLOAT] [-dcb STR] [-dcw STR] [-i] [-pdl] [-gsp PATH] [-ppp PATH] [--version] [-wcdf FILEPATH]
#                         PDF_FILE [PDF_FILE ...]
# Error in pdf-crop-margins (pdfCropMargins): argument -a/--absoluteOffset: invalid float value: 'll'
#
# Cropping: /Users/amin/Desktop/33/test/LT_AVXL_NOTE_6.22.21.pdf
# Saving cropped file to: /Users/amin/Desktop/33/test/cropped/LT_AVXL_NOTE_6.22.21_cropped.pdf
# Output:
# Error:
# Usage: pdf-crop-margins [-h] [-o OUTFILE_PATH_OR_DIR] [-v] [-gui] [-p PCT] [-p4 PCT PCT PCT PCT] [-pt] [-a BP] [-a4 BP BP BP BP] [-cs] [-csm4 BP BP BP BP] [-ap BP] [-ap4 BP BP BP BP] [-u] [-m INT]
#                         [-m4 INT INT INT INT] [-mp INT] [-s] [-ms INT] [-e] [-g PAGESTR] [-c [d|m|p|gr|gb|o]] [-gs] [-gsr] [-t BYTEVAL] [-nb INT] [-ns INT] [-x DPI] [-y DPI] [-sr STR] [-gf INT]
#                         [-b [m|c|t|a|b]] [-f [m|c|t|a|b]] [-r] [-A] [-gsf] [-nc] [-pv PROG] [-mo] [-q] [-nco] [-pf] [-sc STR] [-su STR] [-ss STR] [-pw PASSWD] [-pc] [-khc] [-kvc] [-spr FLOAT:FLOAT]
#                         [-prw FLOAT FLOAT FLOAT FLOAT] [-dcb STR] [-dcw STR] [-i] [-pdl] [-gsp PATH] [-ppp PATH] [--version] [-wcdf FILEPATH]
#                         PDF_FILE [PDF_FILE ...]
# Error in pdf-crop-margins (pdfCropMargins): argument -a/--absoluteOffset: invalid float value: 'll'
#
# Cropping: /Users/amin/Desktop/33/test/LT_PHGE_IOC_4.15.21.pdf
# Saving cropped file to: /Users/amin/Desktop/33/test/cropped/LT_PHGE_IOC_4.15.21_cropped.pdf
# Output:
# Error:
# Usage: pdf-crop-margins [-h] [-o OUTFILE_PATH_OR_DIR] [-v] [-gui] [-p PCT] [-p4 PCT PCT PCT PCT] [-pt] [-a BP] [-a4 BP BP BP BP] [-cs] [-csm4 BP BP BP BP] [-ap BP] [-ap4 BP BP BP BP] [-u] [-m INT]
#                         [-m4 INT INT INT INT] [-mp INT] [-s] [-ms INT] [-e] [-g PAGESTR] [-c [d|m|p|gr|gb|o]] [-gs] [-gsr] [-t BYTEVAL] [-nb INT] [-ns INT] [-x DPI] [-y DPI] [-sr STR] [-gf INT]
#                         [-b [m|c|t|a|b]] [-f [m|c|t|a|b]] [-r] [-A] [-gsf] [-nc] [-pv PROG] [-mo] [-q] [-nco] [-pf] [-sc STR] [-su STR] [-ss STR] [-pw PASSWD] [-pc] [-khc] [-kvc] [-spr FLOAT:FLOAT]
#                         [-prw FLOAT FLOAT FLOAT FLOAT] [-dcb STR] [-dcw STR] [-i] [-pdl] [-gsp PATH] [-ppp PATH] [--version] [-wcdf FILEPATH]
#                         PDF_FILE [PDF_FILE ...]
# Error in pdf-crop-margins (pdfCropMargins): argument -a/--absoluteOffset: invalid float value: 'll'
#
# Cropping: /Users/amin/Desktop/33/test/Graviton Corporate Presentation July 2022.pdf
# Saving cropped file to: /Users/amin/Desktop/33/test/cropped/Graviton Corporate Presentation July 2022_cropped.pdf
# Output:
# Error:
# Usage: pdf-crop-margins [-h] [-o OUTFILE_PATH_OR_DIR] [-v] [-gui] [-p PCT] [-p4 PCT PCT PCT PCT] [-pt] [-a BP] [-a4 BP BP BP BP] [-cs] [-csm4 BP BP BP BP] [-ap BP] [-ap4 BP BP BP BP] [-u] [-m INT]
#                         [-m4 INT INT INT INT] [-mp INT] [-s] [-ms INT] [-e] [-g PAGESTR] [-c [d|m|p|gr|gb|o]] [-gs] [-gsr] [-t BYTEVAL] [-nb INT] [-ns INT] [-x DPI] [-y DPI] [-sr STR] [-gf INT]
#                         [-b [m|c|t|a|b]] [-f [m|c|t|a|b]] [-r] [-A] [-gsf] [-nc] [-pv PROG] [-mo] [-q] [-nco] [-pf] [-sc STR] [-su STR] [-ss STR] [-pw PASSWD] [-pc] [-khc] [-kvc] [-spr FLOAT:FLOAT]
#                         [-prw FLOAT FLOAT FLOAT FLOAT] [-dcb STR] [-dcw STR] [-i] [-pdl] [-gsp PATH] [-ppp PATH] [--version] [-wcdf FILEPATH]
#                         PDF_FILE [PDF_FILE ...]
# Error in pdf-crop-margins (pdfCropMargins): argument -a/--absoluteOffset: invalid float value: 'll'
#
# Cropping: /Users/amin/Desktop/33/test/Bectas Tx Non-Con - Aug.1.2022.pdf
# Saving cropped file to: /Users/amin/Desktop/33/test/cropped/Bectas Tx Non-Con - Aug.1.2022_cropped.pdf
# Output:
# Error:
# Usage: pdf-crop-margins [-h] [-o OUTFILE_PATH_OR_DIR] [-v] [-gui] [-p PCT] [-p4 PCT PCT PCT PCT] [-pt] [-a BP] [-a4 BP BP BP BP] [-cs] [-csm4 BP BP BP BP] [-ap BP] [-ap4 BP BP BP BP] [-u] [-m INT]
#                         [-m4 INT INT INT INT] [-mp INT] [-s] [-ms INT] [-e] [-g PAGESTR] [-c [d|m|p|gr|gb|o]] [-gs] [-gsr] [-t BYTEVAL] [-nb INT] [-ns INT] [-x DPI] [-y DPI] [-sr STR] [-gf INT]
#                         [-b [m|c|t|a|b]] [-f [m|c|t|a|b]] [-r] [-A] [-gsf] [-nc] [-pv PROG] [-mo] [-q] [-nco] [-pf] [-sc STR] [-su STR] [-ss STR] [-pw PASSWD] [-pc] [-khc] [-kvc] [-spr FLOAT:FLOAT]
#                         [-prw FLOAT FLOAT FLOAT FLOAT] [-dcb STR] [-dcw STR] [-i] [-pdl] [-gsp PATH] [-ppp PATH] [--version] [-wcdf FILEPATH]
#                         PDF_FILE [PDF_FILE ...]
# Error in pdf-crop-margins (pdfCropMargins): argument -a/--absoluteOffset: invalid float value: 'll'
#
# Cropping: /Users/amin/Desktop/33/test/20 080822_PRTA_Research Summary.pdf
# Saving cropped file to: /Users/amin/Desktop/33/test/cropped/20 080822_PRTA_Research Summary_cropped.pdf
# Output:
# Error:
# Usage: pdf-crop-margins [-h] [-o OUTFILE_PATH_OR_DIR] [-v] [-gui] [-p PCT] [-p4 PCT PCT PCT PCT] [-pt] [-a BP] [-a4 BP BP BP BP] [-cs] [-csm4 BP BP BP BP] [-ap BP] [-ap4 BP BP BP BP] [-u] [-m INT]
#                         [-m4 INT INT INT INT] [-mp INT] [-s] [-ms INT] [-e] [-g PAGESTR] [-c [d|m|p|gr|gb|o]] [-gs] [-gsr] [-t BYTEVAL] [-nb INT] [-ns INT] [-x DPI] [-y DPI] [-sr STR] [-gf INT]
#                         [-b [m|c|t|a|b]] [-f [m|c|t|a|b]] [-r] [-A] [-gsf] [-nc] [-pv PROG] [-mo] [-q] [-nco] [-pf] [-sc STR] [-su STR] [-ss STR] [-pw PASSWD] [-pc] [-khc] [-kvc] [-spr FLOAT:FLOAT]
#                         [-prw FLOAT FLOAT FLOAT FLOAT] [-dcb STR] [-dcw STR] [-i] [-pdl] [-gsp PATH] [-ppp PATH] [--version] [-wcdf FILEPATH]
#                         PDF_FILE [PDF_FILE ...]
# Error in pdf-crop-margins (pdfCropMargins): argument -a/--absoluteOffset: invalid float value: 'll'
#
# Cropping: /Users/amin/Desktop/33/test/CT one-pager Dec 22.pdf
# Saving cropped file to: /Users/amin/Desktop/33/test/cropped/CT one-pager Dec 22_cropped.pdf
# Output:
# Error:
# Usage: pdf-crop-margins [-h] [-o OUTFILE_PATH_OR_DIR] [-v] [-gui] [-p PCT] [-p4 PCT PCT PCT PCT] [-pt] [-a BP] [-a4 BP BP BP BP] [-cs] [-csm4 BP BP BP BP] [-ap BP] [-ap4 BP BP BP BP] [-u] [-m INT]
#                         [-m4 INT INT INT INT] [-mp INT] [-s] [-ms INT] [-e] [-g PAGESTR] [-c [d|m|p|gr|gb|o]] [-gs] [-gsr] [-t BYTEVAL] [-nb INT] [-ns INT] [-x DPI] [-y DPI] [-sr STR] [-gf INT]
#                         [-b [m|c|t|a|b]] [-f [m|c|t|a|b]] [-r] [-A] [-gsf] [-nc] [-pv PROG] [-mo] [-q] [-nco] [-pf] [-sc STR] [-su STR] [-ss STR] [-pw PASSWD] [-pc] [-khc] [-kvc] [-spr FLOAT:FLOAT]
#                         [-prw FLOAT FLOAT FLOAT FLOAT] [-dcb STR] [-dcw STR] [-i] [-pdl] [-gsp PATH] [-ppp PATH] [--version] [-wcdf FILEPATH]
#                         PDF_FILE [PDF_FILE ...]
# Error in pdf-crop-margins (pdfCropMargins): argument -a/--absoluteOffset: invalid float value: 'll'
#
# Cropping: /Users/amin/Desktop/33/test/221003_PRE_Numab Non-Confidential Presentation.pdf
# Saving cropped file to: /Users/amin/Desktop/33/test/cropped/221003_PRE_Numab Non-Confidential Presentation_cropped.pdf
# Output:
# Error:
# Usage: pdf-crop-margins [-h] [-o OUTFILE_PATH_OR_DIR] [-v] [-gui] [-p PCT] [-p4 PCT PCT PCT PCT] [-pt] [-a BP] [-a4 BP BP BP BP] [-cs] [-csm4 BP BP BP BP] [-ap BP] [-ap4 BP BP BP BP] [-u] [-m INT]
#                         [-m4 INT INT INT INT] [-mp INT] [-s] [-ms INT] [-e] [-g PAGESTR] [-c [d|m|p|gr|gb|o]] [-gs] [-gsr] [-t BYTEVAL] [-nb INT] [-ns INT] [-x DPI] [-y DPI] [-sr STR] [-gf INT]
#                         [-b [m|c|t|a|b]] [-f [m|c|t|a|b]] [-r] [-A] [-gsf] [-nc] [-pv PROG] [-mo] [-q] [-nco] [-pf] [-sc STR] [-su STR] [-ss STR] [-pw PASSWD] [-pc] [-khc] [-kvc] [-spr FLOAT:FLOAT]
#                         [-prw FLOAT FLOAT FLOAT FLOAT] [-dcb STR] [-dcw STR] [-i] [-pdl] [-gsp PATH] [-ppp PATH] [--version] [-wcdf FILEPATH]
#                         PDF_FILE [PDF_FILE ...]
# Error in pdf-crop-margins (pdfCropMargins): argument -a/--absoluteOffset: invalid float value: 'll'
# Cropping: /Users/amin/Desktop/33/test/2022-3-18 Apeximmune non-confidential Baird.pdf
# Saving cropped file to: /Users/amin/Desktop/33/test/cropped/2022-3-18 Apeximmune non-confidential Baird_cropped.pdf
# Output:
# Error:
# Usage: pdf-crop-margins [-h] [-o OUTFILE_PATH_OR_DIR] [-v] [-gui] [-p PCT] [-p4 PCT PCT PCT PCT] [-pt] [-a BP] [-a4 BP BP BP BP] [-cs] [-csm4 BP BP BP BP] [-ap BP] [-ap4 BP BP BP BP] [-u] [-m INT]
#                         [-m4 INT INT INT INT] [-mp INT] [-s] [-ms INT] [-e] [-g PAGESTR] [-c [d|m|p|gr|gb|o]] [-gs] [-gsr] [-t BYTEVAL] [-nb INT] [-ns INT] [-x DPI] [-y DPI] [-sr STR] [-gf INT]
#                         [-b [m|c|t|a|b]] [-f [m|c|t|a|b]] [-r] [-A] [-gsf] [-nc] [-pv PROG] [-mo] [-q] [-nco] [-pf] [-sc STR] [-su STR] [-ss STR] [-pw PASSWD] [-pc] [-khc] [-kvc] [-spr FLOAT:FLOAT]
#                         [-prw FLOAT FLOAT FLOAT FLOAT] [-dcb STR] [-dcw STR] [-i] [-pdl] [-gsp PATH] [-ppp PATH] [--version] [-wcdf FILEPATH]
#                         PDF_FILE [PDF_FILE ...]
# Error in pdf-crop-margins (pdfCropMargins): argument -a/--absoluteOffset: invalid float value: 'll'
#
# Cropping: /Users/amin/Desktop/33/test/Alto Overview_April 2022.pdf
# Saving cropped file to: /Users/amin/Desktop/33/test/cropped/Alto Overview_April 2022_cropped.pdf
# Output:
# Error:
# Usage: pdf-crop-margins [-h] [-o OUTFILE_PATH_OR_DIR] [-v] [-gui] [-p PCT] [-p4 PCT PCT PCT PCT] [-pt] [-a BP] [-a4 BP BP BP BP] [-cs] [-csm4 BP BP BP BP] [-ap BP] [-ap4 BP BP BP BP] [-u] [-m INT]
#                         [-m4 INT INT INT INT] [-mp INT] [-s] [-ms INT] [-e] [-g PAGESTR] [-c [d|m|p|gr|gb|o]] [-gs] [-gsr] [-t BYTEVAL] [-nb INT] [-ns INT] [-x DPI] [-y DPI] [-sr STR] [-gf INT]
#                         [-b [m|c|t|a|b]] [-f [m|c|t|a|b]] [-r] [-A] [-gsf] [-nc] [-pv PROG] [-mo] [-q] [-nco] [-pf] [-sc STR] [-su STR] [-ss STR] [-pw PASSWD] [-pc] [-khc] [-kvc] [-spr FLOAT:FLOAT]
#                         [-prw FLOAT FLOAT FLOAT FLOAT] [-dcb STR] [-dcw STR] [-i] [-pdl] [-gsp PATH] [-ppp PATH] [--version] [-wcdf FILEPATH]
#                         PDF_FILE [PDF_FILE ...]
# Error in pdf-crop-margins (pdfCropMargins): argument -a/--absoluteOffset: invalid float value: 'll'
#
# Cropping: /Users/amin/Desktop/33/test/[NON-NDA] Integral Overview.pdf
# Saving cropped file to: /Users/amin/Desktop/33/test/cropped/[NON-NDA] Integral Overview_cropped.pdf
# FloatObject (b'0.00-5677566') invalid; use 0.0 instead
# Output:
# Error:
# Usage: pdf-crop-margins [-h] [-o OUTFILE_PATH_OR_DIR] [-v] [-gui] [-p PCT] [-p4 PCT PCT PCT PCT] [-pt] [-a BP] [-a4 BP BP BP BP] [-cs] [-csm4 BP BP BP BP] [-ap BP] [-ap4 BP BP BP BP] [-u] [-m INT]
#                         [-m4 INT INT INT INT] [-mp INT] [-s] [-ms INT] [-e] [-g PAGESTR] [-c [d|m|p|gr|gb|o]] [-gs] [-gsr] [-t BYTEVAL] [-nb INT] [-ns INT] [-x DPI] [-y DPI] [-sr STR] [-gf INT]
#                         [-b [m|c|t|a|b]] [-f [m|c|t|a|b]] [-r] [-A] [-gsf] [-nc] [-pv PROG] [-mo] [-q] [-nco] [-pf] [-sc STR] [-su STR] [-ss STR] [-pw PASSWD] [-pc] [-khc] [-kvc] [-spr FLOAT:FLOAT]
#                         [-prw FLOAT FLOAT FLOAT FLOAT] [-dcb STR] [-dcw STR] [-i] [-pdl] [-gsp PATH] [-ppp PATH] [--version] [-wcdf FILEPATH]
#                         PDF_FILE [PDF_FILE ...]
# Error in pdf-crop-margins (pdfCropMargins): argument -a/--absoluteOffset: invalid float value: 'll'
#
# Cropping: /Users/amin/Desktop/33/test/JMP_NXTC_IOC_5.26.20.pdf
# Saving cropped file to: /Users/amin/Desktop/33/test/cropped/JMP_NXTC_IOC_5.26.20_cropped.pdf
# Output:
# Error:
# Usage: pdf-crop-margins [-h] [-o OUTFILE_PATH_OR_DIR] [-v] [-gui] [-p PCT] [-p4 PCT PCT PCT PCT] [-pt] [-a BP] [-a4 BP BP BP BP] [-cs] [-csm4 BP BP BP BP] [-ap BP] [-ap4 BP BP BP BP] [-u] [-m INT]
#                         [-m4 INT INT INT INT] [-mp INT] [-s] [-ms INT] [-e] [-g PAGESTR] [-c [d|m|p|gr|gb|o]] [-gs] [-gsr] [-t BYTEVAL] [-nb INT] [-ns INT] [-x DPI] [-y DPI] [-sr STR] [-gf INT]
#                         [-b [m|c|t|a|b]] [-f [m|c|t|a|b]] [-r] [-A] [-gsf] [-nc] [-pv PROG] [-mo] [-q] [-nco] [-pf] [-sc STR] [-su STR] [-ss STR] [-pw PASSWD] [-pc] [-khc] [-kvc] [-spr FLOAT:FLOAT]
#                         [-prw FLOAT FLOAT FLOAT FLOAT] [-dcb STR] [-dcw STR] [-i] [-pdl] [-gsp PATH] [-ppp PATH] [--version] [-wcdf FILEPATH]
#                         PDF_FILE [PDF_FILE ...]
# Error in pdf-crop-margins (pdfCropMargins): argument -a/--absoluteOffset: invalid float value: 'll'
#
# Cropping: /Users/amin/Desktop/33/test/Flare Non-Con Deck November 2022.pdf
# Saving cropped file to: /Users/amin/Desktop/33/test/cropped/Flare Non-Con Deck November 2022_cropped.pdf
# Output:
# Error:
# Usage: pdf-crop-margins [-h] [-o OUTFILE_PATH_OR_DIR] [-v] [-gui] [-p PCT] [-p4 PCT PCT PCT PCT] [-pt] [-a BP] [-a4 BP BP BP BP] [-cs] [-csm4 BP BP BP BP] [-ap BP] [-ap4 BP BP BP BP] [-u] [-m INT]
#                         [-m4 INT INT INT INT] [-mp INT] [-s] [-ms INT] [-e] [-g PAGESTR] [-c [d|m|p|gr|gb|o]] [-gs] [-gsr] [-t BYTEVAL] [-nb INT] [-ns INT] [-x DPI] [-y DPI] [-sr STR] [-gf INT]
#                         [-b [m|c|t|a|b]] [-f [m|c|t|a|b]] [-r] [-A] [-gsf] [-nc] [-pv PROG] [-mo] [-q] [-nco] [-pf] [-sc STR] [-su STR] [-ss STR] [-pw PASSWD] [-pc] [-khc] [-kvc] [-spr FLOAT:FLOAT]
#                         [-prw FLOAT FLOAT FLOAT FLOAT] [-dcb STR] [-dcw STR] [-i] [-pdl] [-gsp PATH] [-ppp PATH] [--version] [-wcdf FILEPATH]
#                         PDF_FILE [PDF_FILE ...]
# Error in pdf-crop-margins (pdfCropMargins): argument -a/--absoluteOffset: invalid float value: 'll'
#
# Cropping: /Users/amin/Desktop/33/test/AscelpiX Corporate Presentation NON CONFIDENTIAL Feb 8 2022.pdf
# Saving cropped file to: /Users/amin/Desktop/33/test/cropped/AscelpiX Corporate Presentation NON CONFIDENTIAL Feb 8 2022_cropped.pdf
#                                             File_name  \
# 0                      Zehna Corporate Deck SymBiosis
# 1                                 PS_TCRR_NOTE_1.5.23
# 2                      Grace Sciece Platform (9.2.20)
# 3                       AcuamarkDx Series A_Corp Deck
# 4                                     coding.bio_deck
# 5         Centurion_BioPharma-Non-Confidential_2021_2
# 6                              JPM_SRZN_NOTE_11.28.22
# 7                                   G_ACET_IOC_4.8.21
# 8                                C_ARQT_NOTE_11.15.22
# 9                                  B_RXRX_IOC_9.21.21
# 10               Dianomi Non-Confidential Slides - v3
# 11                           KBC_MAAT.FR_IOC_12.14.21
# 12                               Engrail Therapeutics
# 13                                 WB_VOR_IOC_1.25.22
# 14                                 E_FNCH_IOC_8.10.21
# 15                                CG_GRNA_IOC_12.8.22
# 16                               LT_AVXL_NOTE_6.22.21
# 17                                LT_PHGE_IOC_4.15.21
# 18          Graviton Corporate Presentation July 2022
# 19                     Bectas Tx Non-Con - Aug.1.2022
# 20                    20 080822_PRTA_Research Summary
# 21                                CT one-pager Dec 22
# 22     221003_PRE_Numab Non-Confidential Presentation
# 23        2022-3-18 Apeximmune non-confidential Baird
# 24                           Alto Overview_April 2022
# 25                        [NON-NDA] Integral Overview
# 26                               JMP_NXTC_IOC_5.26.20
# 27                   Flare Non-Con Deck November 2022
# 28  AscelpiX Corporate Presentation NON CONFIDENTI...
#
#                                          PyPDF2_SpaCy  \
# 0                                               DECKA
# 1                             TCR2 Therapeutics, Inc.
# 2                         Conﬁdential & Proprietary.1
# 3                                            Accurate
# 4                         Leukapheresis Manufacturing
# 5   Non-ConfidentialTargeted \nCancer \nTherapiesC...
# 6                       North America Equity Research
# 7                                   Financial Metrics
# 8                            ken.cacciatore@cowen.com
# 9                         Recursion \nPharmaceuticals
# 10                          DianomiTherapeutics, Inc.
# 11                                     KBC Securities
# 12                                 neuroscienceUnique
# 13  Dennis.Pak@wedbush.com\n \n  \nCompany Informa...
# 14                                        Health Care
# 15                                 US Equity Research
# 16                    Biotechnology\nEstimate Changes
# 17                                                BUY
# 18    Graviton Biopharmaceuticals Holding Corporation
# 19                                 BectasTherapeutics
# 20                                      Prothena Corp
# 21                     the Oxford University Founders
# 22                                                 TM
# 23             Confidential MaterialsStrategic Vision
# 24                                                MDD
# 25                                           INTEGRAL
# 26            Industry Overview - Initiating Coverage
# 27                                             ENGINE
# 28                                      Johns Hopkins
#
#                                        pdfminer_SpaCy  pdfrw_SpaCy
# 0                                                DECK          NaN
# 1                             TCR2 Therapeutics, Inc.          NaN
# 2                                                 LLC          NaN
# 3                                    Universal Access          NaN
# 4                                             Isolate          NaN
# 5                        Albumin Companion Diagnostic          NaN
# 6                                          Capital IQ          NaN
# 7                 Price Target\n\n  Financial Metrics          NaN
# 8                                     EQUITY RESEARCH          NaN
# 9                         Recursion \nPharmaceuticals          NaN
# 10       Confidential & Not For External Distribution          NaN
# 11                                            Bossche          NaN
# 12                                       NEUROSCIENCE          NaN
# 13  Dennis.Pak@wedbush.com\n\n   \n\n \n\n \n\nCom...          NaN
# 14                                        Health Care          NaN
# 15           Sustainability - Agriculture & Food Tech          NaN
# 16                    Biotechnology\nEstimate Changes          NaN
# 17                                                BUY          NaN
# 18  Graviton Biopharmaceuticals Holding Corporatio...          NaN
# 19  Bectas\nTherapeutics\n\nDynamic Precision & Se...          NaN
# 20            Prothena Corporation \nResearch Summary          NaN
# 21                                 Investor Relations          NaN
# 22                                       Lambda-CapTM          NaN
# 23                                                CMC          NaN
# 24                                                MDD          NaN
# 25                               Molecule Development          NaN
# 26            Industry Overview - Initiating Coverage          NaN
# 27                                          • Initial          NaN
# 28                                      Johns Hopkins          NaN
